# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import pandas as pd
import os
import io
import time

import string
from string import digits

# %% [markdown]
# # Load Data
# Download English Arabic dataset. The data is available here: Data source: http://www.manythings.org/anki/

# %%
# Path to the data txt file on disk.
raw_data_path = 'C:\\Users\\Alrayan\\Desktop\\Machine Learning Transition\\Data\\ara.txt'
lines = pd.read_csv(raw_data_path,delimiter="\t",names=['input_texts', 'target_texts', 'notes'])
# Return the DataFrame head
lines.head()
# Out:
#   input_texts target_texts                                              notes
# 0         Hi.      مرحبًا.  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1        Run!        اركض!  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 2       Help!      النجدة!  CC-BY 2.0 (France) Attribution: tatoeba.org #4...
# 3       Jump!        اقفز!  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 4       Stop!          قف!  CC-BY 2.0 (France) Attribution: tatoeba.org #4...

# %% [markdown]
# # Explantory Data Analysis

# %%
# Return the dimensionality of the DataFrame.
lines.shape
# Out:
# (11320, 3)

# %%
# Return information about the DataFrame including the index dtype and column dtypes, non-null values and memory usage.
lines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11320 entries, 0 to 11319
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   input_texts   11320 non-null  object
#  1   target_texts  11320 non-null  object
#  2   notes         11320 non-null  object
# dtypes: object(3)
# memory usage: 265.4+ KB

# %% [markdown]
# # Data Pre-Processing
# This section is to perform some data cleaning and preparation.

# %%
# Remove a column by specifying label names 
lines = lines.drop(columns='notes')

# %%
# Lowercase all characters
lines.input_texts=lines.input_texts.apply(lambda x: x.lower())
lines.target_texts=lines.target_texts.apply(lambda x: x.lower())

# %%
# Remove quotes
lines.input_texts=lines.input_texts.apply(lambda x: re.sub("'", '', x))
lines.target_texts=lines.target_texts.apply(lambda x: re.sub("'", '', x))

# %%
# Set of all special characters
english_punctuations = set(string.punctuation)
arabic_punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
# Remove all the special characters
lines.input_texts=lines.input_texts.apply(lambda x: ''.join(ch for ch in x if ch not in english_punctuations))
lines.target_texts=lines.target_texts.apply(lambda x: ''.join(ch for ch in x if ch not in arabic_punctuations))

# %%
# Remove Arabic diacritics from text
lines.target_texts=lines.target_texts.apply(lambda x: re.sub("[ ّ َ ً ُ ٌ ِ ٍ ْ]", " ", x))

#  ّ    | # Tashdid
#  َ    | # Fatha
#  ً    | # Tanwin Fath
#  ُ    | # Damma
#  ٌ    | # Tanwin Damm
#  ِ    | # Kasra
#  ٍ    | # Tanwin Kasr
#  ْ    | # Sukun

# %%
# Remove all numbers from text
remove_digits = str.maketrans('', '', digits)
lines.input_texts=lines.input_texts.apply(lambda x: x.translate(remove_digits))
lines.target_texts=lines.target_texts.apply(lambda x: re.sub("[١٢٣٤٥٦٧٨٩٠]", "", x))

# %%
# Remove extra spaces
lines.input_texts=lines.input_texts.apply(lambda x: x.strip())
lines.target_texts=lines.target_texts.apply(lambda x: x.strip())
lines.input_texts=lines.input_texts.apply(lambda x: re.sub(" +", " ", x))
lines.target_texts=lines.target_texts.apply(lambda x: re.sub(" +", " ", x))

# %%
# Add start and end tokens to target sequences
lines.input_texts=lines.input_texts.apply (lambda x : '<start> '+ x + ' <end>')
lines.target_texts=lines.target_texts.apply(lambda x : '<start> '+ x + ' <end>')

# %%
lines.to_csv(r'C:\\Users\\Alrayan\\Desktop\\Machine Learning Transition\\Data\\arabic.txt', header=None, index=None, sep='\t', mode='a')

# %% [markdown]
# # Text Data Vectorization
# This section is to victorize the data and compute the vocabulary for both English and Arabic. Main steps:
# - compute the vocabulary sizes,
# - compute the length of maximum sequence for both languages,
# - create dictionaries to convert a given token into an integer index and vice-versa.

# %%
batch_size = 64  # Batch size for training.
epochs = 100 #umber of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 30
# Number of unique output tokens: 81
# Max sequence length for inputs: 65
# Max sequence length for outputs: 90

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %% [markdown]
# # Model Development

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 127s 16ms/step - loss: 0.8005 - accuracy: 0.8038 - val_loss: 0.9593 - val_accuracy: 0.7614
# Epoch 2/50
# 8000/8000 [==============================] - 131s 16ms/step - loss: 0.5847 - accuracy: 0.8514 - val_loss: 0.8585 - val_accuracy: 0.7783
# Epoch 3/50
# 8000/8000 [==============================] - 140s 18ms/step - loss: 0.5253 - accuracy: 0.8620 - val_loss: 0.7929 - val_accuracy: 0.7911
# Epoch 4/50
# 8000/8000 [==============================] - 145s 18ms/step - loss: 0.4990 - accuracy: 0.8670 - val_loss: 0.7696 - val_accuracy: 0.7951
# Epoch 5/50
# 8000/8000 [==============================] - 144s 18ms/step - loss: 0.4829 - accuracy: 0.8697 - val_loss: 0.7436 - val_accuracy: 0.7988
# Epoch 6/50
# 8000/8000 [==============================] - 136s 17ms/step - loss: 0.4818 - accuracy: 0.8706 - val_loss: 0.7351 - val_accuracy: 0.8020
# Epoch 7/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.4545 - accuracy: 0.8759 - val_loss: 0.7161 - val_accuracy: 0.8042
# Epoch 8/50
# 8000/8000 [==============================] - 150s 19ms/step - loss: 0.4461 - accuracy: 0.8775 - val_loss: 0.7113 - val_accuracy: 0.8058
# Epoch 9/50
# 8000/8000 [==============================] - 148s 19ms/step - loss: 0.4351 - accuracy: 0.8800 - val_loss: 0.6946 - val_accuracy: 0.8102
# Epoch 10/50
# 8000/8000 [==============================] - 150s 19ms/step - loss: 0.4252 - accuracy: 0.8826 - val_loss: 0.6926 - val_accuracy: 0.8114
# Epoch 11/50
# 8000/8000 [==============================] - 145s 18ms/step - loss: 0.4161 - accuracy: 0.8849 - val_loss: 0.6770 - val_accuracy: 0.8148
# Epoch 12/50
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.4072 - accuracy: 0.8873 - val_loss: 0.6714 - val_accuracy: 0.8161
# Epoch 13/50
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.3992 - accuracy: 0.8892 - val_loss: 0.6640 - val_accuracy: 0.8192
# Epoch 14/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3915 - accuracy: 0.8915 - val_loss: 0.6524 - val_accuracy: 0.8212
# Epoch 15/50
# 8000/8000 [==============================] - 140s 17ms/step - loss: 0.3841 - accuracy: 0.8933 - val_loss: 0.6523 - val_accuracy: 0.8219
# Epoch 16/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3773 - accuracy: 0.8951 - val_loss: 0.6470 - val_accuracy: 0.8241
# Epoch 17/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3706 - accuracy: 0.8968 - val_loss: 0.6423 - val_accuracy: 0.8247
# Epoch 18/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.3640 - accuracy: 0.8986 - val_loss: 0.6445 - val_accuracy: 0.8253
# Epoch 19/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.3578 - accuracy: 0.9001 - val_loss: 0.6359 - val_accuracy: 0.8266
# Epoch 20/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.3518 - accuracy: 0.9018 - val_loss: 0.6374 - val_accuracy: 0.8274
# Epoch 21/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.3459 - accuracy: 0.9037 - val_loss: 0.6401 - val_accuracy: 0.8278
# Epoch 22/50
# 8000/8000 [==============================] - 150s 19ms/step - loss: 0.3401 - accuracy: 0.9049 - val_loss: 0.6431 - val_accuracy: 0.8279
# Epoch 23/50
# 8000/8000 [==============================] - 225s 28ms/step - loss: 0.3345 - accuracy: 0.9066 - val_loss: 0.6425 - val_accuracy: 0.8288
# Epoch 24/50
# 8000/8000 [==============================] - 165s 21ms/step - loss: 0.3290 - accuracy: 0.9080 - val_loss: 0.6416 - val_accuracy: 0.8296
# Epoch 25/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.3238 - accuracy: 0.9093 - val_loss: 0.6383 - val_accuracy: 0.8299
# Epoch 26/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3184 - accuracy: 0.9108 - val_loss: 0.6434 - val_accuracy: 0.8298
# Epoch 27/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3136 - accuracy: 0.9120 - val_loss: 0.6464 - val_accuracy: 0.8295
# Epoch 28/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3082 - accuracy: 0.9135 - val_loss: 0.6493 - val_accuracy: 0.8298
# Epoch 29/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.3035 - accuracy: 0.9147 - val_loss: 0.6543 - val_accuracy: 0.8293
# Epoch 30/50
# 8000/8000 [==============================] - 146s 18ms/step - loss: 0.2984 - accuracy: 0.9159 - val_loss: 0.6549 - val_accuracy: 0.8294
# Epoch 31/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.2936 - accuracy: 0.9173 - val_loss: 0.6609 - val_accuracy: 0.8293
# Epoch 32/50
# 8000/8000 [==============================] - 136s 17ms/step - loss: 0.2888 - accuracy: 0.9186 - val_loss: 0.6656 - val_accuracy: 0.8290
# Epoch 33/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.2845 - accuracy: 0.9198 - val_loss: 0.6813 - val_accuracy: 0.8277
# Epoch 34/50
# 8000/8000 [==============================] - 136s 17ms/step - loss: 0.2801 - accuracy: 0.9209 - val_loss: 0.6769 - val_accuracy: 0.8277
# Epoch 35/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2756 - accuracy: 0.9222 - val_loss: 0.6843 - val_accuracy: 0.8281
# Epoch 36/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.2714 - accuracy: 0.9234 - val_loss: 0.6863 - val_accuracy: 0.8270
# Epoch 37/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2672 - accuracy: 0.9246 - val_loss: 0.6931 - val_accuracy: 0.8277
# Epoch 38/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.2633 - accuracy: 0.9256 - val_loss: 0.6993 - val_accuracy: 0.8264
# Epoch 39/50
# 8000/8000 [==============================] - 137s 17ms/step - loss: 0.2593 - accuracy: 0.9268 - val_loss: 0.7182 - val_accuracy: 0.8258
# Epoch 40/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2556 - accuracy: 0.9278 - val_loss: 0.7235 - val_accuracy: 0.8256
# Epoch 41/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.2516 - accuracy: 0.9289 - val_loss: 0.7255 - val_accuracy: 0.8245
# Epoch 42/50
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.2482 - accuracy: 0.9295 - val_loss: 0.7283 - val_accuracy: 0.8258
# Epoch 43/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2445 - accuracy: 0.9308 - val_loss: 0.7354 - val_accuracy: 0.8242
# Epoch 44/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2411 - accuracy: 0.9318 - val_loss: 0.7375 - val_accuracy: 0.8241
# Epoch 45/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.2379 - accuracy: 0.9324 - val_loss: 0.7512 - val_accuracy: 0.8239
# Epoch 46/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2346 - accuracy: 0.9335 - val_loss: 0.7554 - val_accuracy: 0.8240
# Epoch 47/50
# 8000/8000 [==============================] - 138s 17ms/step - loss: 0.2315 - accuracy: 0.9345 - val_loss: 0.7587 - val_accuracy: 0.8238
# Epoch 48/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.2284 - accuracy: 0.9352 - val_loss: 0.7712 - val_accuracy: 0.8231
# Epoch 49/50
# 8000/8000 [==============================] - 139s 17ms/step - loss: 0.2254 - accuracy: 0.9362 - val_loss: 0.7765 - val_accuracy: 0.8234
# Epoch 50/50
# 8000/8000 [==============================] - 141s 18ms/step - loss: 0.2224 - accuracy: 0.9369 - val_loss: 0.7940 - val_accuracy: 0.8228

# %%
# Save model
model.save('s2s.h5')

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(200):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: <start> start hi end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start run end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start help end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start jump end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stop end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go on end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go on end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hello end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hurry end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hurry end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i see end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i won end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start relax end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start smile end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start cheers end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start got it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start he ran end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i know end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i know end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i know end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im ok end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start listen end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start no way end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start really end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start thanks end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start why me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start awesome end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start be cool end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start call me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start call me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come in end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come in end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come on end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come on end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come on end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start get out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start get out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start get out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go away end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go away end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go away end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start goodbye end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start he came end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start he runs end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start help me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start help me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im sad end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start me too end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start shut up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start shut up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start shut up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start shut up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stop it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start take it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tell me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom won end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom won end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start wake up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start welcome end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start welcome end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start welcome end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start welcome end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who won end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who won end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start why not end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start why not end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start have fun end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hurry up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i forgot end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i got it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
# -
# Input sentence: <start> start i got it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i got it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i use it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start ill pay end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im busy end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im busy end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im cold end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im free end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im here end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im home end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im poor end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im rich end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start it hurts end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start its hot end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start its new end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start lets go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start lets go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start lets go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start lets go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start lets go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start look out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start look out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start look out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start speak up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stand up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start terrific end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start terrific end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom died end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom died end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom left end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom lied end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom lost end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom quit end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start try some end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who am i end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who died end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who died end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start after you end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start birds fly end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start birds fly end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start bless you end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start calm down end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start can we go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come here end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come here end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start come home end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start did i win end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start do it now end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start dont lie end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start excuse me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start fantastic end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start forget it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start forget it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start forget it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start forget it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start forget me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go inside end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start go to bed end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start good luck end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start goodnight end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start goodnight end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hands off end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start he is ill end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start he is ill end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hows tom end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start hows tom end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i am thai end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i am cold end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i am okay end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i am sure end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
# -
# Input sentence: <start> start i hope so end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i laughed end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i like it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i love it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start i see tom end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im a boy end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im a kid end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im a man end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im alone end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im bored end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im broke end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im happy end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im lucky end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im needy end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im ready end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im ready end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im sorry end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im sorry end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im sorry end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im sorry end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start im tired end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start is it new end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start its cold end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start its late end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start let me go end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start listen up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start look back end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start of course end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start of course end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start of course end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start of course end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start of course end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start pardon me end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start seriously end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start she walks end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stay away end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stay thin end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stay thin end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stay thin end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stop that end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stop that end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start stop them end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start take care end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start take care end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start take care end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start take care end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start thank you end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start then what end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start then what end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom moved end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start tom waved end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start watch out end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start were hot end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start whats up end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who cares end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who is it end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who knows end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start who knows end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
#
# -
# Input sentence: <start> start wonderful end <end>
# Decoded sentence: <start> start أنا أعرف أنك ما زلت تحبيني end <end>
